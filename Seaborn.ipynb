# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
#in seaborn we don't use the format of the file
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # in Seaborn it is mandatory to provide x value , y value and data(through which file you are getting dataset)

# %%
#difference between seaborn and matplob here are we don't have to give labels one by one. either you can pass it in paramter
sns.relplot(x = 'total_bill' , y = 'tip' , data = tips)

# %%
#here hue is used. hue is upgraded version of legend in seaborn. it will show specific data given in parameter.
# understand how data showing in the graph. 
#the graph is showing the data of total_bill and tip. from 0 the points is getting high that mean the person's total_bill is higher than other and tip is higher than other.
#now the colored point rise means, person's total_bill and tip is high and he is smoker. as you can see smoker's value yes/no.
#so, these are the comparison graph of the data given 
sns.relplot(x = 'total_bill' , y = 'tip' , data = tips , hue = 'smoker' )

# %%
#here data will be shown with two comparison. here style kwargs will change the point style as per comparison of data.
# Now the data is showing like circle and cross mark.
#the circle mark is showing that the total_bill, tip, not a smoker and had choosen lunch.
#and cross mark is showing that total_bill,tip, smoker, and had choosen dinner
sns.relplot(x = 'total_bill' , y = 'tip' , data = tips , hue = 'smoker' ,style = 'time')

# %%
# now here we are using size kwarg with value size of the dataset, 
#it is differentiating the data by sizes of the circle as you can see in the graph
sns.relplot(x = 'total_bill' , y = 'tip' , data = tips , hue = 'smoker' ,style = 'time' , size = 'size')

# %%
#if you want to separate the data into two part for more clearance . you can use it row or col. it will separate and draw two graph.
# now the data is like for first one is showing howmany have lunch with all other aspects and 2nd graph for howmany have dinner with other aspects too.
sns.relplot(x = 'total_bill' , y = 'tip' , data = tips , hue = 'smoker' ,style = 'size' , row = 'time')

# %% [markdown]
# hue = show data with different color for more ease
# style = shape(cross, circle,etc)
# size = size(or can say parameter of the data which

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# to see first 10 data 
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
# for scatterplot
sns.scatterplot( x = "sepal_length" , y = "petal_length" , data = iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.relplot( x = "sepal_length" , y = "petal_length" , data = iris)

# %%
#it is different kind of graph plot which show
sns.catplot( x = "sepal_length" , y = "petal_length" , data = iris)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#this is catplot
sns.catplot( x = "day" , y = "total_bill" , data = tips)

# %%
#jitter for not spreading the points from line
sns.catplot( x = "day" , y = "total_bill" , data = tips , jitter = False)

# %%
sns.catplot( x = "day" , y = "total_bill" , data = tips , kind = "swarm")

# %%
# this kind is mostly used . here the box showing that at that place big number of data vary. the line inside box shows the mean of that data 
sns.catplot( x = "day" , y = "total_bill" , data = tips , kind = "box")

# %%
#this kind will shows like violin . inside violin the bold line denote density of data point denotes mean
sns.catplot( x = "day" , y = "total_bill" , data = tips , kind = "violin")

# %%
# here we are taking random hundred data
x = np.random.randn(100)
print(x)
sns.displot(x , kde = False)
# Out:
# [ 1.66339656 -1.51761632  0.44187833  0.79053566 -2.1272881  -0.27235698
#  -0.68225295  0.15172617  0.38011307 -1.68265438 -0.11177546 -0.14519574
#   1.61916377  0.63645611 -0.42095623  0.66220579  1.87394534 -0.15137186
#   0.04313292 -0.34301966  1.30103553 -1.21547061 -0.62448446 -0.5833036
#   0.11880674  0.53950263  0.7032747   1.20698794 -0.07395862  0.1981968
#  -1.56680238 -0.77206627 -0.86621648 -0.41600297 -0.70928185  3.03565013
#   0.66875488 -1.19324483  0.23842278 -0.60412837  1.15630423 -0.40652898
#  -2.0411788  -0.29992407 -3.16190136 -0.62445564  0.15941526  1.04009563
#   1.58556487 -1.84547918  0.71416203 -0.4492446  -0.20854416 -0.62693252
#   0.44411056  0.72271482 -0.23601551  1.31113917  1.1346392  -1.45586095
#   0.08806647 -0.64082389  1.56964093 -0.75205736  0.47191557  2.28961427
#   0.138233    0.11879398  0.44277692  0.52341044  0.0709945   0.12677416
#  -1.19742087 -0.11477743  1.02059788 -0.89574448  0.22815111 -0.66722062
# ...

# %%
#here displot is also new kind of graph plot. here Kde is basically for derivation of density of data like standard deviation
x = np.random.randn(100)
sns.displot(x , kde = True)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot( x = "total_bill" , data = tips , kde = True)

# %%
# joint plot will simply join two data set and show its replica

sns.jointplot( x = "total_bill" , y = "tip" , data = tips)

# %%
# Pairplots
#it will take every parameter of the dataset will show every different plot.
sns.pairplot(tips)

# %%
sns.pairplot(iris)

# %%
import Seaborn as sns
df = pd.read_csv("train.csv")
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# these are the data given. you have to use plot for visualisation the profit with differenet entity
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
#the describe fn will tell the count of data, mean , standard deviation, min, 25% means 1st quartile,50% 2nd quartile,75% 3rd quartile, maximum 
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
#you can check the count by using len(dataset name)
len(df)
# Out:
# 50

# %%
# kde - kernel density estimate - it tells the density inside graph where many data vary.
sns.displot ( x = "R&D Spend" , data = df , kde = True , bins = 25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_140852/20506329.py in <module>
#       1 # kde - kernel density estimate - it tells the density inside graph where many data vary.
# ----> 2 sns.displot ( x = "R&D Spend" , data = df , kde = True , bins = 25)
#
# NameError: name 'df' is not defined

# %%
# Using matplolib
import matplotlib.pyplot as plt
plt.scatter( x = "R&D Spend" , y = "Profit" , data = df)
plt.xlabel("R&D Spend")
plt.ylabel("Profit")
plt.title("R&D Spend VS Profit")
plt.show()

# %% [markdown]
# * Positive relation
# * linear relation
# * Majority is in between 50K - 100K

# %%
import matplotlib.pyplot as plt
plt.scatter( x = "Administration" , y = "Profit" , data = df)
plt.xlabel("Administration")
plt.ylabel("Profit")
plt.title("Administration VS Profit")
plt.show()
plt.savefig("Administration_VS_Profit.png")

# %% [markdown]
# * There is no relation between the adm and the profit

# %%
sns.scatterplot(x = "Administration" , y = "Profit" , data =df)
# Out:
# <AxesSubplot:xlabel='Administration', ylabel='Profit'>

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sns.scatterplot(x = "R&D Spend" , y = "Profit" , data =df , hue = "State")
plt.show()

# %%
sns.relplot(x = "R&D Spend" , y = "Profit" , data =df , col = "State")
plt.show()
